# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Removing stop words

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jhonpatriot/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
en_stopwords = stopwords.words("english")

# %%
 print(en_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
sentence = "it was too far to go to the shop and he did not want her to walk"

# %%
" ".join([word for word in sentence.split() if word not in en_stopwords])
# Out:
# 'far go shop want walk'

# %%
en_stopwords.remove("did")
en_stopwords.remove("not")

# %%
en_stopwords.append("go")

# %%
sentence_no_stopwords_custom = " ".join([word for word in sentence.split() if word not in en_stopwords])

# %%
sentence_no_stopwords_custom
# Out:
# 'far shop did not want walk'

# %% [markdown]
# ## Regular expressions

# %%
import re

# %%
result_search = re.search("pattern", r"string to contain the pattern")

# %%
print(result_search)
# Out:
# <re.Match object; span=(22, 29), match='pattern'>

# %%
result_search_2 = re.search("pattern", r"the phrase to fined isn't in this string")

# %%
print(result_search_2)
# Out:
# None

# %%
string = r"sara was able to help me find the items needed quickly"

# %%
new_string = re.sub("sara", "sarah", string)

# %%
print(new_string)
# Out:
# sarah was able to help me find the items needed quickly

# %%
customer_reviews = [
    "sam was a great help to me in the store",
    "the cashier was very rude to me, I think her name was eleanor",
    "amazing work from sadeen!",
    "sarah was able to help me find the items I needed quickly",
    "lucy is such a great addition to the team",
    "great service from sara she found me what i wanted",
]

# %%
sarahs_reviews = []

# %%
pattern_to_find = r'sarah?'

# %%
for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        sarahs_reviews.append(string)

# %%
print(sarahs_reviews)
# Out:
# ['sarah was able to help me find the items I needed quickly', 'great service from sara she found me what i wanted']

# %%
a_reviews = []
pattern_to_find = r"^a"

# %%
for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        a_reviews.append(string)

# %%
print(a_reviews)
# Out:
# ['amazing work from sadeen!']

# %%
y_reviews = []
pattern_to_find = r"y$"

for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        y_reviews.append(string)

# %%
print(y_reviews)
# Out:
# ['sarah was able to help me find the items I needed quickly']

# %%
need_want_reviews = []
pattern_to_find = r"(need|want)ed"

for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        need_want_reviews.append(string)

# %%
print(need_want_reviews)
# Out:
# ['sarah was able to help me find the items I needed quickly', 'great service from sara she found me what i wanted']

# %%
no_punct_reviews = []
pattern_to_find = r"[^\w\s]"

for string in customer_reviews:
    no_punct_string = re.sub(pattern_to_find, "", string)
    no_punct_reviews.append(no_punct_string)

# %%
print(no_punct_reviews)
# Out:
# ['sam was a great help to me in the store', 'the cashier was very rude to me I think her name was eleanor', 'amazing work from sadeen', 'sarah was able to help me find the items I needed quickly', 'lucy is such a great addition to the team', 'great service from sara she found me what i wanted']
